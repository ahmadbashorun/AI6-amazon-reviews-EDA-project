# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Fashion

# %%
fashion = pd.read_json('AMAZON_FASHION_5.json', lines=True)

# %%
fashion.head()
# Out:
#    overall  verified  reviewTime     reviewerID        asin  \
# 0        5      True  09 4, 2015  ALJ66O1Y6SLHA  B000K2PJ4K
# 1        5      True  09 4, 2015  ALJ66O1Y6SLHA  B000K2PJ4K
# 2        5      True  09 4, 2015  ALJ66O1Y6SLHA  B000K2PJ4K
# 3        5      True  09 4, 2015  ALJ66O1Y6SLHA  B000K2PJ4K
# 4        5      True  09 4, 2015  ALJ66O1Y6SLHA  B000K2PJ4K
#
#                                                style reviewerName  \
# 0   {'Size:': ' Big Boys', 'Color:': ' Blue/Orange'}     Tonya B.
# 1  {'Size:': ' Big Boys', 'Color:': ' Black (3746...     Tonya B.
# 2  {'Size:': ' Big Boys', 'Color:': ' Blue/Gray L...     Tonya B.
# 3  {'Size:': ' Big Boys', 'Color:': ' Blue (37867...     Tonya B.
# 4     {'Size:': ' Big Boys', 'Color:': ' Blue/Pink'}     Tonya B.
#
#                  reviewText     summary  unixReviewTime  vote image
# 0  Great product and price!  Five Stars      1441324800   NaN   NaN
# 1  Great product and price!  Five Stars      1441324800   NaN   NaN
# ...

# %%
fashion = pd.concat([fashion.drop('style', axis=1), fashion['style'].apply(pd.Series)], axis = 1)

# %%
fashion.head()
# Out:
#    overall  verified  reviewTime     reviewerID        asin reviewerName  \
# 0        5      True  09 4, 2015  ALJ66O1Y6SLHA  B000K2PJ4K     Tonya B.
# 1        5      True  09 4, 2015  ALJ66O1Y6SLHA  B000K2PJ4K     Tonya B.
# 2        5      True  09 4, 2015  ALJ66O1Y6SLHA  B000K2PJ4K     Tonya B.
# 3        5      True  09 4, 2015  ALJ66O1Y6SLHA  B000K2PJ4K     Tonya B.
# 4        5      True  09 4, 2015  ALJ66O1Y6SLHA  B000K2PJ4K     Tonya B.
#
#                  reviewText     summary  unixReviewTime  vote image   0  \
# 0  Great product and price!  Five Stars      1441324800   NaN   NaN NaN
# 1  Great product and price!  Five Stars      1441324800   NaN   NaN NaN
# 2  Great product and price!  Five Stars      1441324800   NaN   NaN NaN
# 3  Great product and price!  Five Stars      1441324800   NaN   NaN NaN
# 4  Great product and price!  Five Stars      1441324800   NaN   NaN NaN
#
#                           Color: Size Name:      Size: Style:
# ...

# %%
fashion = fashion.drop([0,'vote','image','Size Name:','Style:'], axis=1)

# %%
fashion.head()
# Out:
#    overall  verified reviewTime     reviewerID        asin reviewerName  \
# 0        5      True 2015-09-04  ALJ66O1Y6SLHA  B000K2PJ4K     Tonya B.
# 1        5      True 2015-09-04  ALJ66O1Y6SLHA  B000K2PJ4K     Tonya B.
# 2        5      True 2015-09-04  ALJ66O1Y6SLHA  B000K2PJ4K     Tonya B.
# 3        5      True 2015-09-04  ALJ66O1Y6SLHA  B000K2PJ4K     Tonya B.
# 4        5      True 2015-09-04  ALJ66O1Y6SLHA  B000K2PJ4K     Tonya B.
#
#                  reviewText     summary  unixReviewTime  \
# 0  Great product and price!  Five Stars      1441324800
# 1  Great product and price!  Five Stars      1441324800
# 2  Great product and price!  Five Stars      1441324800
# 3  Great product and price!  Five Stars      1441324800
# 4  Great product and price!  Five Stars      1441324800
#
#                           Color:      Size:
# 0                    Blue/Orange   Big Boys
# 1   Black (37467610) / Red/White   Big Boys
# 2                 Blue/Gray Logo   Big Boys
# ...

# %%
fashion['reviewTime'] = pd.to_datetime(fashion['reviewTime'])

# %%
fashion['summary'].nunique()
# Out:
# 274

# %%
fashion = fashion.drop('unixReviewTime', axis=1)
# fashion.reset_index(drop=True)
fashion.head()
# Out:
#    overall  verified reviewTime     reviewerID        asin reviewerName  \
# 0        5      True 2015-09-04  ALJ66O1Y6SLHA  B000K2PJ4K     Tonya B.
# 1        5      True 2015-09-04  ALJ66O1Y6SLHA  B000K2PJ4K     Tonya B.
# 2        5      True 2015-09-04  ALJ66O1Y6SLHA  B000K2PJ4K     Tonya B.
# 3        5      True 2015-09-04  ALJ66O1Y6SLHA  B000K2PJ4K     Tonya B.
# 4        5      True 2015-09-04  ALJ66O1Y6SLHA  B000K2PJ4K     Tonya B.
#
#                  reviewText                         Color:      Size:
# 0  Great product and price!                    Blue/Orange   Big Boys
# 1  Great product and price!   Black (37467610) / Red/White   Big Boys
# 2  Great product and price!                 Blue/Gray Logo   Big Boys
# 3  Great product and price!    Blue (37867638-99) / Yellow   Big Boys
# 4  Great product and price!                      Blue/Pink   Big Boys

# %%
fashion.to_csv('Amazon_Fashio.csv')

# %%
plt.scatter('overall','reviewerID')

# %% [markdown]
# ### Beauty

# %%
beauty = pd.read_json('All_Beauty_5.json', lines=True)
beauty.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        5      True   09 1, 2016  A3CIUOJXQ5VDQ2  B0000530HU
# 1        5      True  11 14, 2013  A3H7T87S984REU  B0000530HU
# 2        1      True  08 18, 2013  A3J034YH7UG4KT  B0000530HU
# 3        5     False   05 3, 2011  A2UEO5XR3598GI  B0000530HU
# 4        5      True   05 6, 2011  A3SFRT223XXWF7  B00006L9LC
#
#                                                style     reviewerName  \
# 0  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...         Shelly F
# 1  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...     houserules18
# 2  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...             Adam
# 3  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...           Rich K
# 4                          {'Size:': ' 200ml/6.7oz'}  C. C. Christian
#
#                                           reviewText  \
# 0                   As advertised. Reasonably priced
# 1  Like the oder and the feel when I put it on my...
# ...

# %%
beauty = pd.concat([beauty.drop('style', axis=1), beauty['style'].apply(pd.Series)], axis = 1)
beauty.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        5      True   09 1, 2016  A3CIUOJXQ5VDQ2  B0000530HU
# 1        5      True  11 14, 2013  A3H7T87S984REU  B0000530HU
# 2        1      True  08 18, 2013  A3J034YH7UG4KT  B0000530HU
# 3        5     False   05 3, 2011  A2UEO5XR3598GI  B0000530HU
# 4        5      True   05 6, 2011  A3SFRT223XXWF7  B00006L9LC
#
#       reviewerName                                         reviewText  \
# 0         Shelly F                   As advertised. Reasonably priced
# 1     houserules18  Like the oder and the feel when I put it on my...
# 2             Adam  I bought this to smell nice after I shave.  Wh...
# 3           Rich K  HEY!! I am an Aqua Velva Man and absolutely lo...
# 4  C. C. Christian  If you ever want to feel pampered by a shampoo...
#
#                                              summary  unixReviewTime vote  \
# 0                                         Five Stars      1472688000  NaN
# ...

# %%
beauty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5269 entries, 0 to 5268
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   overall         5269 non-null   int64
#  1   verified        5269 non-null   bool
#  2   reviewTime      5269 non-null   object
#  3   reviewerID      5269 non-null   object
#  4   asin            5269 non-null   object
#  5   reviewerName    5269 non-null   object
#  6   reviewText      5264 non-null   object
#  7   summary         5264 non-null   object
#  8   unixReviewTime  5269 non-null   int64
#  9   vote            552 non-null    object
#  10  image           98 non-null     object
#  11  0               0 non-null      float64
#  12  Color:          378 non-null    object
#  13  Design:         21 non-null     object
#  14  Flavor:         12 non-null     object
#  15  Scent Name:     10 non-null     object
#  16  Size:           4358 non-null   object
# ...

# %%
beauty = beauty.drop([0,'vote','image','Scent Name:','Style Name:', 'Flavor:', 'unixReviewTime', 'summary', 'Color:', 'Design:'], axis=1)
beauty.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        5      True   09 1, 2016  A3CIUOJXQ5VDQ2  B0000530HU
# 1        5      True  11 14, 2013  A3H7T87S984REU  B0000530HU
# 2        1      True  08 18, 2013  A3J034YH7UG4KT  B0000530HU
# 3        5     False   05 3, 2011  A2UEO5XR3598GI  B0000530HU
# 4        5      True   05 6, 2011  A3SFRT223XXWF7  B00006L9LC
#
#       reviewerName                                         reviewText  \
# 0         Shelly F                   As advertised. Reasonably priced
# 1     houserules18  Like the oder and the feel when I put it on my...
# 2             Adam  I bought this to smell nice after I shave.  Wh...
# 3           Rich K  HEY!! I am an Aqua Velva Man and absolutely lo...
# 4  C. C. Christian  If you ever want to feel pampered by a shampoo...
#
#           Size:
# 0        7.0 oz
# 1        7.0 oz
# 2        7.0 oz
# 3        7.0 oz
# 4   200ml/6.7oz

# %%
beauty['reviewTime'] = pd.to_datetime(beauty['reviewTime'])
beauty.head()
# Out:
#    overall  verified reviewTime      reviewerID        asin     reviewerName  \
# 0        5      True 2016-09-01  A3CIUOJXQ5VDQ2  B0000530HU         Shelly F
# 1        5      True 2013-11-14  A3H7T87S984REU  B0000530HU     houserules18
# 2        1      True 2013-08-18  A3J034YH7UG4KT  B0000530HU             Adam
# 3        5     False 2011-05-03  A2UEO5XR3598GI  B0000530HU           Rich K
# 4        5      True 2011-05-06  A3SFRT223XXWF7  B00006L9LC  C. C. Christian
#
#                                           reviewText         Size:
# 0                   As advertised. Reasonably priced        7.0 oz
# 1  Like the oder and the feel when I put it on my...        7.0 oz
# 2  I bought this to smell nice after I shave.  Wh...        7.0 oz
# 3  HEY!! I am an Aqua Velva Man and absolutely lo...        7.0 oz
# 4  If you ever want to feel pampered by a shampoo...   200ml/6.7oz

# %%
beauty.to_csv('beauty.csv')

# %% [markdown]
# ### Appliances

# %%
appliances = pd.read_json('Appliances_5.json', lines=True)
appliances.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        5      True  08 22, 2013  A34A1UP40713F8  B00009W3I4
# 1        5      True   02 8, 2016  A1AHW6I678O6F2  B00009W3PA
# 2        5      True   08 5, 2015   A8R48NKTGCJDQ  B00009W3PA
# 3        5      True  04 24, 2015   AR3OHHHW01A8E  B00009W3PA
# 4        5      True  03 21, 2015  A2CIEGHZ7L1WWR  B00009W3PA
#
#                        style     reviewerName  \
# 0  {'Style:': ' Dryer Vent'}    James. Backus
# 1       {'Size:': ' 6-Foot'}           kevin.
# 2       {'Size:': ' 6-Foot'}        CDBrannom
# 3       {'Size:': ' 6-Foot'}  Calvin E Reames
# 4       {'Size:': ' 6-Foot'}   albert j. kong
#
#                                           reviewText        summary  \
# 0  I like this as a vent as well as something tha...  Great product
# 1                                          good item     Five Stars
# 2                     Fit my new LG dryer perfectly.     Five Stars
# ...

# %%
appliances = appliances.drop(['summary'], axis=1)
appliances.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        5      True  08 22, 2013  A34A1UP40713F8  B00009W3I4
# 1        5      True   02 8, 2016  A1AHW6I678O6F2  B00009W3PA
# 2        5      True   08 5, 2015   A8R48NKTGCJDQ  B00009W3PA
# 3        5      True  04 24, 2015   AR3OHHHW01A8E  B00009W3PA
# 4        5      True  03 21, 2015  A2CIEGHZ7L1WWR  B00009W3PA
#
#       reviewerName                                         reviewText vote  \
# 0    James. Backus  I like this as a vent as well as something tha...  NaN
# 1           kevin.                                          good item  NaN
# 2        CDBrannom                     Fit my new LG dryer perfectly.  NaN
# 3  Calvin E Reames                     Good value for electric dryers  NaN
# 4   albert j. kong                  Price and delivery was excellent.  NaN
#
#   image
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
appliances.to_csv('appliances.csv')

# %%
appliances.vote.nunique()
# Out:
# 16

# %% [markdown]
# ### Fashion Jerry

# %%
fashion = pd.read_csv('Amazon_Fashio.csv')

# %%
fashion.head()
# Out:
#    overall  verified reviewTime     reviewerID        asin reviewerName  \
# 0        5      True 2015-09-04  ALJ66O1Y6SLHA  B000K2PJ4K     Tonya B.
# 1        5      True 2015-09-04  ALJ66O1Y6SLHA  B000K2PJ4K     Tonya B.
# 2        5      True 2015-09-04  ALJ66O1Y6SLHA  B000K2PJ4K     Tonya B.
# 3        5      True 2015-09-04  ALJ66O1Y6SLHA  B000K2PJ4K     Tonya B.
# 4        5      True 2015-09-04  ALJ66O1Y6SLHA  B000K2PJ4K     Tonya B.
#
#                  reviewText                         Color:      Size:
# 0  Great product and price!                    Blue/Orange   Big Boys
# 1  Great product and price!   Black (37467610) / Red/White   Big Boys
# 2  Great product and price!                 Blue/Gray Logo   Big Boys
# 3  Great product and price!    Blue (37867638-99) / Yellow   Big Boys
# 4  Great product and price!                      Blue/Pink   Big Boys

# %%
fashion = fashion.drop('Unnamed: 0', axis=1)

# %%
fashion['reviewTime'] = pd.to_datetime(fashion['reviewTime'])

# %% [markdown]
# ### A sublot showing both review count and mean per asin

# %%
# fashion.groupby('asin').count().sort_values('overall', ascending = False)
# Out:
#             overall  verified  reviewTime  reviewerID  reviewerName  \
# asin
# B009MA34NY      377       377         377         377           377
# B005AGO4LU      376       376         376         376           376
# B010RRWKT4      376       376         376         376           376
# B0092UF54A      376       376         376         376           376
# B014IBJKNO      375       375         375         375           375
# B0014F7B98      374       374         374         374           374
# B0058YEJ5K      367       367         367         367           367
# B001IKJOLW      365       365         365         365           365
# B000YFSR5G       56        56          56          56            56
# B000YFSR4W       36        36          36          36            36
# B000K2PJ4K       10        10          10          10            10
# B0017LGD34       10        10          10          10            10
# B0017LD0BM       10        10          10          10            10
# ...

# %%
axes1 = fashion.groupby('asin').count()
axes2 = fashion.groupby('asin').mean()

# %%
key = [key for key, df in fashion.groupby('asin')]

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.bar(key, axes1.overall, color = 'r')
ax2.plot(key, axes2.overall, color = 'b')
ax1.set_xticklabels(key, rotation = 90)
ax1.set_ylabel('Review count', color = 'r')
ax2.set_ylabel('mean rating', color = 'b')
ax1.set_title('review count vs avg rating')
plt.show()

# %% [markdown]
# ### Most review done in a day per ID

# %%
time_id = fashion.groupby(['reviewTime', 'reviewerID']).count().sort_values('overall', ascending=False)

# %%
time_id[['overall']]
# Out:
#                            overall
# reviewTime reviewerID
# 2017-03-08 A37K0VP2H8FKOU       16
# 2017-11-27 A3OP70LPLALBKN       16
# 2017-05-19 AT7UEQ7UJB0RU        16
# 2018-02-01 A3VGHF7VNFBMCQ        9
# 2017-04-14 AFD4WKNPLPS3I         8
# ...                            ...
# 2017-07-25 A3UTTXFSBNV2V7        1
# 2016-02-14 A2YI41MCJB2QCV        1
# 2017-07-19 A12DWXDNZQTKXQ        1
# 2017-06-25 A1Z8U8IPBLBEU5        1
# 2016-08-28 A3LJRA2I5F34W5        1
#
# [434 rows x 1 columns]

# %% [markdown]
# do a chart of count and mean, group asin
# date with the highest reviews
# what customers buy more
# how many items were bought (2 most) together using cust id and date

# %% [markdown]
# ### Beauty Ahmad

# %%
beauty_df = pd.read_csv("beauty.csv")

# %%
beauty_df.head()
# Out:
#    Unnamed: 0  overall  verified  reviewTime      reviewerID        asin  \
# 0           0        5      True  2016-09-01  A3CIUOJXQ5VDQ2  B0000530HU
# 1           1        5      True  2013-11-14  A3H7T87S984REU  B0000530HU
# 2           2        1      True  2013-08-18  A3J034YH7UG4KT  B0000530HU
# 3           3        5     False  2011-05-03  A2UEO5XR3598GI  B0000530HU
# 4           4        5      True  2011-05-06  A3SFRT223XXWF7  B00006L9LC
#
#       reviewerName                                         reviewText  \
# 0         Shelly F                   As advertised. Reasonably priced
# 1     houserules18  Like the oder and the feel when I put it on my...
# 2             Adam  I bought this to smell nice after I shave.  Wh...
# 3           Rich K  HEY!! I am an Aqua Velva Man and absolutely lo...
# 4  C. C. Christian  If you ever want to feel pampered by a shampoo...
#
#           Size:
# 0        7.0 oz
# 1        7.0 oz
# 2        7.0 oz
# 3        7.0 oz
# 4   200ml/6.7oz

# %%
del beauty_df["Unnamed: 0"]

# %%
beauty_df['reviewTime'] = pd.to_datetime(beauty_df['reviewTime'])
#beauty_df.head()

# %%
beauty_df.rename(columns={"overall":"productRating","asin":"productID", "Size:":"size"}, inplace=True)
beauty_df.head()
# Out:
#    productRating  verified reviewTime      reviewerID   productID  \
# 0              5      True 2016-09-01  A3CIUOJXQ5VDQ2  B0000530HU
# 1              5      True 2013-11-14  A3H7T87S984REU  B0000530HU
# 2              1      True 2013-08-18  A3J034YH7UG4KT  B0000530HU
# 3              5     False 2011-05-03  A2UEO5XR3598GI  B0000530HU
# 4              5      True 2011-05-06  A3SFRT223XXWF7  B00006L9LC
#
#       reviewerName                                         reviewText  \
# 0         Shelly F                   As advertised. Reasonably priced
# 1     houserules18  Like the oder and the feel when I put it on my...
# 2             Adam  I bought this to smell nice after I shave.  Wh...
# 3           Rich K  HEY!! I am an Aqua Velva Man and absolutely lo...
# 4  C. C. Christian  If you ever want to feel pampered by a shampoo...
#
#            size
# 0        7.0 oz
# 1        7.0 oz
# 2        7.0 oz
# 3        7.0 oz
# 4   200ml/6.7oz

# %%
beauty_df.groupby('productID').count().sort_values('productRating', ascending = False)
# Out:
#             productRating  verified  reviewTime  reviewerID  reviewerName  \
# productID
# B0012Y0ZG2           1794      1794        1794        1794          1794
# B000URXP6E            858       858         858         858           858
# B001OHV1H4            489       489         489         489           489
# B00006L9LC            489       489         489         489           489
# B0009RF9DW            392       392         392         392           392
# ...                   ...       ...         ...         ...           ...
# B00MGK9Z8U              1         1           1           1             1
# B0091OCA86              1         1           1           1             1
# B00B7V273E              1         1           1           1             1
# B00GHJOM2U              1         1           1           1             1
# B01DKQAXC0              1         1           1           1             1
#
#             reviewText  size
# productID
# ...

# %% [markdown]
# #### The Data at a glance

# %%
beauty_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5269 entries, 0 to 5268
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   productRating  5269 non-null   int64
#  1   verified       5269 non-null   bool
#  2   reviewTime     5269 non-null   datetime64[ns]
#  3   reviewerID     5269 non-null   object
#  4   productID      5269 non-null   object
#  5   reviewerName   5269 non-null   object
#  6   reviewText     5264 non-null   object
#  7   size           4358 non-null   object
# dtypes: bool(1), datetime64[ns](1), int64(1), object(5)
# memory usage: 293.4+ KB

# %%
beauty_df.isnull().sum()
# Out:
# productRating      0
# verified           0
# reviewTime         0
# reviewerID         0
# productID          0
# reviewerName       0
# reviewText         5
# size             911
# dtype: int64

# %% [markdown]
#  I renamed the columns to clearer terms, I also figured I have 911 null values in size

# %% [markdown]
# #### Analysis with datetimes

# %%
time_span = beauty_df["reviewTime"].max() - beauty_df["reviewTime"].min()

print ("Time span of the data: {}".format(time_span))
# Out:
# Time span of the data: 5084 days 00:00:00

# %%
beauty_df["year"] = beauty_df["reviewTime"].dt.year
beauty_df["month"] = beauty_df["reviewTime"].dt.month_name()
beauty_df["dayOfTheWeek"] = beauty_df["reviewTime"].dt.day_name()

# %%
year_count = beauty_df.groupby("year")["reviewText"].count().sort_values(ascending=False)

print("Amount of reviews per year: \n{}".format(year_count))
# Out:
# Amount of reviews per year:
# year
# 2016    1232
# 2015    1027
# 2017     825
# 2014     784
# 2013     756
# 2018     443
# 2012     111
# 2009      25
# 2011      20
# 2008      20
# 2007      13
# 2010       4
# 2006       2
# 2005       1
# 2004       1
# Name: reviewText, dtype: int64

# %%
month_count = beauty_df.groupby("month")["reviewText"].count().sort_values(ascending=False)

print("Amount of reviews per month: \n{}".format(month_count))
# Out:
# Amount of reviews per month:
# month
# August       598
# September    550
# April        548
# March        518
# July         464
# May          445
# February     413
# January      410
# December     352
# November     338
# October      320
# June         308
# Name: reviewText, dtype: int64

# %%
year_month_count = beauty_df.groupby(["year", "month"])["reviewText"].count().sort_values(ascending=False)

print ("Monthly breakdown of amount of reviews for each year: \n{}".format(year_month_count))
# Out:
# Monthly breakdown of amount of reviews for each year:
# year  month
# 2017  September    244
# 2018  April        184
# 2016  July         177
#       March        175
# 2015  August       159
#                   ...
# 2008  November       1
# 2009  February       1
#       May            1
# 2018  July           1
# 2004  September      1
# Name: reviewText, Length: 101, dtype: int64

# %%
yearly_rating = beauty_df.groupby("year")["productRating"].agg(["count","mean"]).sort_values(
    by="count", ascending=False)

print("Average rating per year: \n{}".format(yearly_rating))
# Out:
# Average rating per year:
#       count      mean
# year
# 2016   1232  4.933442
# 2015   1032  4.932171
# 2017    825  4.713939
# 2014    784  4.891582
# 2013    756  4.880952
# 2018    443  3.724605
# 2012    111  4.927928
# 2009     25  4.680000
# 2008     20  3.200000
# 2011     20  4.400000
# 2007     13  4.230769
# 2010      4  5.000000
# 2006      2  5.000000
# 2004      1  5.000000
# 2005      1  5.000000

# %%
yearly_month_rating = beauty_df.groupby(["year", "month"])["productRating"].agg(["count","mean"]).sort_values(
    by="count", ascending=False)

print("Monthly breakdown for average rating per year: \n{}".format(yearly_month_rating))
# Out:
# Monthly breakdown for average rating per year:
#                 count      mean
# year month
# 2017 September    244  4.368852
# 2018 April        184  4.157609
# 2016 July         177  4.830508
#      March        175  5.000000
# 2015 August       159  4.974843
# ...               ...       ...
# 2009 March          1  1.000000
#      February       1  5.000000
# 2008 November       1  2.000000
#      January        1  3.000000
# 2004 September      1  5.000000
#
# [101 rows x 2 columns]

# %% [markdown]
# I created new columns for month, year and day of the week. I also grouped based on amount of reviews as well as average rating

# %% [markdown]
# ### Appliances Hamzat

# %%
appliances_df = pd.read_csv("appliances.csv")

# %%
appliances_df.head()
# Out:
#    Unnamed: 0  overall  verified   reviewTime      reviewerID        asin  \
# 0           0        5      True  08 22, 2013  A34A1UP40713F8  B00009W3I4
# 1           1        5      True   02 8, 2016  A1AHW6I678O6F2  B00009W3PA
# 2           2        5      True   08 5, 2015   A8R48NKTGCJDQ  B00009W3PA
# 3           3        5      True  04 24, 2015   AR3OHHHW01A8E  B00009W3PA
# 4           4        5      True  03 21, 2015  A2CIEGHZ7L1WWR  B00009W3PA
#
#       reviewerName                                         reviewText vote  \
# 0    James. Backus  I like this as a vent as well as something tha...  NaN
# 1           kevin.                                          good item  NaN
# 2        CDBrannom                     Fit my new LG dryer perfectly.  NaN
# 3  Calvin E Reames                     Good value for electric dryers  NaN
# 4   albert j. kong                  Price and delivery was excellent.  NaN
#
#   image
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
appliances_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2277 entries, 0 to 2276
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    2277 non-null   int64
#  1   overall       2277 non-null   int64
#  2   verified      2277 non-null   bool
#  3   reviewTime    2277 non-null   object
#  4   reviewerID    2277 non-null   object
#  5   asin          2277 non-null   object
#  6   reviewerName  2277 non-null   object
#  7   reviewText    2277 non-null   object
#  8   vote          2074 non-null   object
#  9   image         828 non-null    object
# dtypes: bool(1), int64(2), object(7)
# memory usage: 162.5+ KB

# %%
appliances_df = appliances_df.drop(['vote','image',], axis=1)
appliances_df.head()
# Out:
#    Unnamed: 0  overall  verified   reviewTime      reviewerID        asin  \
# 0           0        5      True  08 22, 2013  A34A1UP40713F8  B00009W3I4
# 1           1        5      True   02 8, 2016  A1AHW6I678O6F2  B00009W3PA
# 2           2        5      True   08 5, 2015   A8R48NKTGCJDQ  B00009W3PA
# 3           3        5      True  04 24, 2015   AR3OHHHW01A8E  B00009W3PA
# 4           4        5      True  03 21, 2015  A2CIEGHZ7L1WWR  B00009W3PA
#
#       reviewerName                                         reviewText
# 0    James. Backus  I like this as a vent as well as something tha...
# 1           kevin.                                          good item
# 2        CDBrannom                     Fit my new LG dryer perfectly.
# 3  Calvin E Reames                     Good value for electric dryers
# 4   albert j. kong                  Price and delivery was excellent.

# %%
del appliances_df["Unnamed: 0"]

# %%
appliances_df['reviewTime'] = pd.to_datetime(appliances_df['reviewTime'])

# %%
appliances_df.rename(columns={"overall":"productRating","asin":"productID",}, inplace=True)
appliances_df.head()
# Out:
#    productRating  verified reviewTime      reviewerID   productID  \
# 0              5      True 2013-08-22  A34A1UP40713F8  B00009W3I4
# 1              5      True 2016-02-08  A1AHW6I678O6F2  B00009W3PA
# 2              5      True 2015-08-05   A8R48NKTGCJDQ  B00009W3PA
# 3              5      True 2015-04-24   AR3OHHHW01A8E  B00009W3PA
# 4              5      True 2015-03-21  A2CIEGHZ7L1WWR  B00009W3PA
#
#       reviewerName                                         reviewText
# 0    James. Backus  I like this as a vent as well as something tha...
# 1           kevin.                                          good item
# 2        CDBrannom                     Fit my new LG dryer perfectly.
# 3  Calvin E Reames                     Good value for electric dryers
# 4   albert j. kong                  Price and delivery was excellent.

# %%
appliances_df.groupby('productRating').sum()
# Out:
#                verified
# productRating
# 1                     4
# 2                     7
# 3                   421
# 4                   222
# 5                  1594

# %%
appliances_df.groupby('productID').count().sort_values('productRating', ascending = False)
# Out:
#             productRating  verified  reviewTime  reviewerID  reviewerName  \
# productID
# B0006GVNOA           2040      2040        2040        2040          2040
# B0014CN8Y8             24        24          24          24            24
# B00JGTUQJ6             13        13          13          13            13
# B0015UGPWQ             12        12          12          12            12
# B004XLDE5A              8         8           8           8             8
# B000XXWOGW              8         8           8           8             8
# B0056I99WG              8         8           8           8             8
# B00CW0O1EW              8         8           8           8             8
# B001DPFP88              7         7           7           7             7
# B000NCTOUM              7         7           7           7             7
# B0053F80JA              7         7           7           7             7
# ...

# %%
appliances_df.isnull().sum()
# Out:
# productRating    0
# verified         0
# reviewTime       0
# reviewerID       0
# productID        0
# reviewerName     0
# reviewText       0
# dtype: int64

# %% [markdown]
# ##### I renamed the columns, grouped by "productRating" and "productID". I want to plot a chart to display the "productRating" against  "verified"...
